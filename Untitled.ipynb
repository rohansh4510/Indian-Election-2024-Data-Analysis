# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd1=pd.read_csv('Indian_result.csv')

# %%
Indian_result=pd.read_csv('Indian_result.csv')

# %%
trailing_party_counts = Indian_result['Trailing Party'].value_counts()

# Get the top 5 parties with the most trailing count
top_5_trailing_parties = trailing_party_counts.head(5)

# Plotting
plt.figure(figsize=(10, 6))
top_5_trailing_parties.plot(kind='bar', color='skyblue')
plt.title('Top 5 Parties with Most Trailing Count')
plt.xlabel('Party')
plt.ylabel('Trailing Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Save top 5 trailing parties data to a new CSV file
top_5_trailing_parties_df = pd.DataFrame(top_5_trailing_parties).reset_index()
top_5_trailing_parties_df.columns = ['Party', 'Trailing Count']

# Specify the file path
output_csv_path = 'top_5_trailing_parties.csv'

# Save to CSV
top_5_trailing_parties_df.to_csv(output_csv_path, index=False)

print(f"Top 5 trailing parties data saved to '{output_csv_path}'")
# Out:
# Top 5 trailing parties data saved to 'top_5_trailing_parties.csv'

# %%
seats_won = Indian_result['Leading Party'].value_counts()

# Get the top 5 parties with the most seats won
top_5_parties = seats_won.head(5)

# Plotting
plt.figure(figsize=(10, 6))
top_5_parties.plot(kind='bar', color='lightgreen')
plt.title('Top 5 Parties with Most Seats Won')
plt.xlabel('Party')
plt.ylabel('Seats Won')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Convert top 5 parties data to a DataFrame
top_5_parties_df = pd.DataFrame(top_5_parties).reset_index()
top_5_parties_df.columns = ['Party', 'Seats Won']

# Specify the file path
output_csv_path = 'top_5_parties_seats_won.csv'

# Save to CSV
top_5_parties_df.to_csv(output_csv_path, index=False)

print(f"Top 5 parties with most seats won data saved to '{output_csv_path}'")
# Out:
# Top 5 parties with most seats won data saved to 'top_5_parties_seats_won.csv'

# %%
state_counts = Indian_result['State'].value_counts()

top_10_states = state_counts.head(10)

plt.figure(figsize=(10, 6))
top_10_states.plot(kind='bar', color='salmon')
plt.title('Top 10 States with Most Constituencies')
plt.xlabel('State')
plt.ylabel('Number of Constituencies')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Convert top 10 states data to a DataFrame
top_10_states_df = pd.DataFrame(top_10_states).reset_index()
top_10_states_df.columns = ['State', 'Number of Constituencies']

# Specify the file path
output_csv_path = 'top_10_states_most_constituencies.csv'

# Save to CSV
top_10_states_df.to_csv(output_csv_path, index=False)

print(f"Top 10 states with most constituencies data saved to '{output_csv_path}'")
# Out:
# Top 10 states with most constituencies data saved to 'top_10_states_most_constituencies.csv'

# %%
state_counts = Indian_result['State'].value_counts()

bottom_10_states = state_counts.tail(10)

plt.figure(figsize=(10, 6))
bottom_10_states.plot(kind='bar', color='lightblue')
plt.title('10 States with Least Constituencies')
plt.xlabel('State')
plt.ylabel('Number of Constituencies')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
bottom_10_states_df = pd.DataFrame(bottom_10_states).reset_index()
bottom_10_states_df.columns = ['State', 'Number of Constituencies']

# Specify the file path
output_csv_path = 'bottom_10_states_least_constituencies.csv'

# Save to CSV
bottom_10_states_df.to_csv(output_csv_path, index=False)

print(f"Bottom 10 states with least constituencies data saved to '{output_csv_path}'")
# Out:
# Bottom 10 states with least constituencies data saved to 'bottom_10_states_least_constituencies.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Indian_result' is your DataFrame containing the data

# Filter data for BJP
bjp_data = Indian_result[Indian_result['Leading Party'] == 'Bharatiya Janata Party']

# Calculate the number of constituencies won by BJP in each state
state_counts_bjp = bjp_data['State'].value_counts()

# Calculate total constituencies in each state
total_constituencies = Indian_result['State'].value_counts()

# Calculate winning percentage for BJP in each state
winning_percentage = (state_counts_bjp / total_constituencies) * 100

# Get the top 10 states with highest winning percentage for BJP
top_10_states_bjp = winning_percentage.sort_values(ascending=False).head(10)

# Plotting (optional)
plt.figure(figsize=(12, 8))
top_10_states_bjp.plot(kind='bar', color='skyblue')
plt.xlabel('State')
plt.ylabel('Winning Percentage (%)')
plt.title('Top 10 States with Highest Winning Percentage for BJP')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Save top 10 states data to a new CSV file
top_10_states_bjp_df = pd.DataFrame(top_10_states_bjp).reset_index()
top_10_states_bjp_df.columns = ['State', 'Winning Percentage']

output_csv_path = 'top_10_states_bjp_winning_percentage.csv'
top_10_states_bjp_df.to_csv(output_csv_path, index=False)

print(f"Top 10 states with highest winning percentage for BJP saved to '{output_csv_path}'")
# Out:
# Top 10 states with highest winning percentage for BJP saved to 'top_10_states_bjp_winning_percentage.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Indian_result' is your DataFrame containing the data

# Filter data for BJP
bjp_data = Indian_result[Indian_result['Leading Party'] == 'Bharatiya Janata Party']

# Group by State and count seats won by BJP
bjp_seat_counts = bjp_data.groupby('State').size().reset_index(name='Seats Won by BJP')

# Get the top 10 states with most seats won by BJP
top_10_states_bjp = bjp_seat_counts.sort_values(by='Seats Won by BJP', ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(top_10_states_bjp['State'], top_10_states_bjp['Seats Won by BJP'], color='lightblue')
plt.xlabel('State')
plt.ylabel('Seats Won by BJP')
plt.title('Top 10 States with Most Seats Won by BJP')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Save top 10 states data to a new CSV file
output_csv_path = 'top_10_states_bjp_seats_won.csv'
top_10_states_bjp.to_csv(output_csv_path, index=False)

print(f"Top 10 states with most seats won by BJP saved to '{output_csv_path}'")
# Out:
# Top 10 states with most seats won by BJP saved to 'top_10_states_bjp_seats_won.csv'

# %%
parties_of_interest = ['Bharatiya Janata Party', 'Indian National Congress', 
                       'All India Trinamool Congress', 'Samajwadi Party', 
                       'Dravida Munnetra Kazhagam (DMK)']

# Convert 'Margin' to numeric (if not already)
Indian_result['Margin'] = pd.to_numeric(Indian_result['Margin'], errors='coerce')

# Filter data for selected parties
filtered_data = Indian_result[Indian_result['Leading Party'].isin(parties_of_interest)]

# Calculate average margin of victory for each party
average_margin = filtered_data.groupby('Leading Party')['Margin'].mean()

# Plotting
plt.figure(figsize=(10, 6))
average_margin.plot(kind='bar', color='skyblue')
plt.title('Average Margin of Victory for Selected Parties')
plt.xlabel('Party')
plt.ylabel('Average Margin of Victory')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
average_margin.to_csv('average_margin_of_victory.csv', header=True)

# %%
bjp_data = Indian_result[Indian_result['Leading Party'] == 'Bharatiya Janata Party']
congress_data = Indian_result[Indian_result['Leading Party'] == 'Indian National Congress']

# Group by state and count seats won
bjp_seat_counts = bjp_data.groupby('State').size().reset_index(name='Seats Won by BJP')
congress_seat_counts = congress_data.groupby('State').size().reset_index(name='Seats Won by Congress')

# Merge BJP and Congress seat counts
merged_counts = pd.merge(bjp_seat_counts, congress_seat_counts, on='State', how='outer').fillna(0)

# Calculate seat difference
merged_counts['Seat Difference'] = abs(merged_counts['Seats Won by BJP'] - merged_counts['Seats Won by Congress'])

# Get top 5 closest fights
closest_fights = merged_counts.sort_values(by='Seat Difference').head(5)

# Plotting
plt.figure(figsize=(12, 8))
plt.bar(closest_fights['State'], closest_fights['Seat Difference'], color='orange')
plt.xlabel('State')
plt.ylabel('Seat Difference (BJP - Congress)')
plt.title('Top 5 States with Closest Fights between BJP and Congress')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Save to CSV
closest_fights.to_csv('closest_fights_bjp_congress.csv', index=False)

# Display the top 5 states with closest fights
print("Top 5 States with Closest Fights between BJP and Congress:")
print(closest_fights[['State', 'Seats Won by BJP', 'Seats Won by Congress', 'Seat Difference']])
# Out:
# Top 5 States with Closest Fights between BJP and Congress:
#                           State  Seats Won by BJP  Seats Won by Congress  \
# 28                    Telangana               8.0                    8.0
# 10                      Haryana               5.0                    5.0
# 8                           Goa               1.0                    1.0
# 0   Andaman and Nicobar Islands               1.0                    0.0
# 24                   Puducherry               0.0                    1.0
#
#     Seat Difference
# 28              0.0
# 10              0.0
# 8               0.0
# 0               1.0
# 24              1.0

# %%
congress_data = Indian_result[Indian_result['Leading Party'] == 'Indian National Congress']

# Group by state and count seats won
congress_seat_counts = congress_data.groupby('State').size().reset_index(name='Seats Won by Congress')

# Get top 5 states with most seats won by Congress
top_5_states_congress = congress_seat_counts.sort_values(by='Seats Won by Congress', ascending=False).head(5)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(top_5_states_congress['State'], top_5_states_congress['Seats Won by Congress'], color='lightgreen')
plt.xlabel('State')
plt.ylabel('Seats Won by Congress')
plt.title('Top 5 States with Most Seats Won by Congress')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Save to CSV
top_5_states_congress.to_csv('top_states_congress_seats.csv', index=False)

# Display the top 5 states with most seats won by Congress
print("Top 5 States with Most Seats Won by Congress:")
print(top_5_states_congress[['State', 'Seats Won by Congress']])
# Out:
# Top 5 States with Most Seats Won by Congress:
#           State  Seats Won by Congress
# 9        Kerala                     14
# 11  Maharashtra                     13
# 19   Tamil Nadu                      9
# 8     Karnataka                      9
# 20    Telangana                      8

# %%
congress_data = Indian_result[Indian_result['Leading Party'] == 'Indian National Congress']

# Count total constituencies by state
seats_by_state = Indian_result.groupby('State')['Constituency'].count().reset_index()

# Count Congress constituencies by state
congress_seats_by_state = congress_data.groupby('State')['Constituency'].count().reset_index()

# Merge data and calculate percentage
merged_data = pd.merge(seats_by_state, congress_seats_by_state, on='State', suffixes=('_total', '_congress'))
merged_data['Percentage'] = (merged_data['Constituency_congress'] / merged_data['Constituency_total']) * 100

# Get top 5 worst performing states for Congress
worst_performing_states = merged_data.sort_values(by='Percentage').head(5)

# Display and print the top 5 worst performing states
top_5_worst_states = worst_performing_states[['State', 'Percentage']]
print("Top 5 states where Congress performed the worst in terms of percentage:")
print(top_5_worst_states)

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(top_5_worst_states['State'], top_5_worst_states['Percentage'], color='blue')
plt.xlabel('States')
plt.ylabel('Percentage of Seats Won by Congress')
plt.title('Top 5 States where Congress Performed the Worst')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Save to CSV
worst_performing_states.to_csv('worst_performing_congress_states.csv', index=False)
# Out:
# Top 5 states where Congress performed the worst in terms of percentage:
#             State  Percentage
# 22    West Bengal    2.380952
# 5         Gujarat    3.846154
# 15         Odisha    4.761905
# 1           Bihar    7.500000
# 21  Uttar Pradesh    7.500000

# %%
state_results = Indian_result.groupby('State').agg({
    'Leading Party': lambda x: x.value_counts().index[0],  
    'Leading Candidate': 'count' 
}).reset_index()

# Calculate BJP seats by state
state_results['BJP Seats'] = Indian_result[Indian_result['Leading Party'] == 'Bharatiya Janata Party'].groupby('State')['Leading Candidate'].count().reset_index()['Leading Candidate']

# Calculate Second Best Party Seats
state_results['Second Best Party Seats'] = state_results.apply(lambda row: row['Leading Candidate'] if row['Leading Party'] == 'Bharatiya Janata Party' else 0, axis=1)

# Get top 10 states with highest Second Best Party Seats
bjp_second_best_states = state_results.sort_values(by='Second Best Party Seats', ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(bjp_second_best_states['State'], bjp_second_best_states['Leading Candidate'], color='blue', label='Best Performing Party')
plt.bar(bjp_second_best_states['State'], bjp_second_best_states['BJP Seats'], color='orange', label='BJP')
plt.xlabel('States')
plt.ylabel('Seats Won')
plt.title('Comparison of Seats Won: Best Performing Party vs BJP')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Save to CSV
bjp_second_best_states.to_csv('bjp_second_best_states_comparison.csv', index=False)
